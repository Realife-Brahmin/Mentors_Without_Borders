# %% [markdown]
# ## Import packages

# %%
using DataFrames
using DelimitedFiles
using Downloads
using CSV
using XLSX
using BenchmarkTools

# %% [markdown]
# I can use download to download a file and store its contents il variable

# %% [markdown]
# P =  download('cloudURL', 'localFile')

# %%
csvURL = "https://raw.githubusercontent.com/nassarhuda/easy_data/master/programming_languages.csv"
localCSVFileName = "programming_languages.csv"
P = Downloads.download(csvURL,localCSVFileName)
# Out:
# "programming_languages.csv"

# %% [markdown]
# To have acces of few data  use ';head localFile

# %%
print(P)
# Out:
# programming_languages.csv

# %% [markdown]
# ## Work with DelimitedFiles package

# %%
P,H = readdlm(localCSVFileName,',';header=true)
# Out:
# (Any[1951 "Regional Assembly Language"; 1952 "Autocode"; … ; 2012 "Julia"; 2014 "Swift"], AbstractString["year" "language"])

# %%
# Write to text file 
textFileName = "programming_language.txt"
writedlm(textFileName, P,'-')

# %%
## Work with CSV package
C =  CSV.read(localCSVFileName, DataFrame)
# Out:
# 73×2 DataFrame
#  Row │ year   language
#      │ Int64  String31
# ─────┼───────────────────────────────────
#    1 │  1951  Regional Assembly Language
#    2 │  1952  Autocode
#    3 │  1954  IPL
#    4 │  1955  FLOW-MATIC
#    5 │  1957  FORTRAN
#    6 │  1957  COMTRAN
#    7 │  1958  LISP
#    8 │  1958  ALGOL 58
#    9 │  1959  FACT
#   10 │  1959  COBOL
#   11 │  1959  RPG
#   ⋮  │   ⋮                ⋮
#   64 │  2006  PowerShell
#   65 │  2007  Clojure
#   66 │  2009  Go
#   67 │  2010  Rust
#   68 │  2011  Dart
#   69 │  2011  Kotlin
#   70 │  2011  Red
#   71 │  2011  Elixir
#   72 │  2012  Julia
#   73 │  2014  Swift
#                           52 rows omitted

# %%
@show typeof(C)
# Out:
# typeof(C) = DataFrame
# DataFrame

# %%
names(C)
# Out:
# 2-element Vector{String}:
#  "year"
#  "language"

# %%
C.year
# Out:
# 73-element Vector{Int64}:
#  1951
#  1952
#  1954
#  1955
#  1957
#  1957
#  1958
#  1958
#  1959
#  1959
#  1959
#  1962
#  1962
#     ⋮
#  2003
#  2005
#  2006
#  2007
#  2009
#  2010
#  2011
#  2011
#  2011
#  2011
#  2012
#  2014

# %%
describe(C)
# Out:
# 2×7 DataFrame
#  Row │ variable  mean     min       median  max        nmissing  eltype
#      │ Symbol    Union…   Any       Union…  Any        Int64     DataType
# ─────┼────────────────────────────────────────────────────────────────────
#    1 │ year      1982.99  1951      1986.0  2014              0  Int64
#    2 │ language           ALGOL 58          dBase III         0  String31

# %%
# Write to a .csv file using CSV package
newCsvFileExportName = "MyExport.csv"
CSV.write(newCsvFileExportName,DataFrame(P,:auto))
# Out:
# "MyExport.csv"

# %% [markdown]
# Trying xlsx package to read excel file
# T =  XLSX.readdata("FileName","SheetName","CellRange")
