# %%
√25
# Out:
# 5.0

# %%
10 ÷ 3
# Out:
# 3

# %%
45 // 50
# Out:
# 9//10

# %%
x=4
5x
# Out:
# 20

# %%
#= 
Mon commentaire

=#

# %%
my_name = """Mon nom"""
first(my_name)
# Out:
# 'M': ASCII/Unicode U+004D (category Lu: Letter, uppercase)

# %%
rand(6,3)
# Out:
# 6×3 Matrix{Float64}:
#  0.932648   0.724175  0.179682
#  0.81489    0.176562  0.83676
#  0.879555   0.721658  0.374893
#  0.892949   0.722059  0.681575
#  0.919638   0.876607  0.331382
#  0.0967684  0.636464  0.798694

# %%
my_array = ["AKE","Moi",7]
# Out:
# 3-element Vector{Any}:
#   "AKE"
#   "Moi"
#  7

# %%
isinteger()

# %%
🤠 = 18
0

# %%
while 🤠 
    
end
