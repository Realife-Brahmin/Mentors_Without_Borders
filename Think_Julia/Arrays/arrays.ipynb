# %% [markdown]
# # Work with Arrays

# %%
emptyArray = []
typeof(emptyArray)
# Out:
# Vector{Any} (alias for Array{Any, 1})

# %% [markdown]
# ## Array are mutable

# %%
myArray = ["Me", 1, 2.3,["Test",true]]
myArray[4]="Fourth item"
myArray[end]="another Test"
print(myArray)
"Me" ∈ myArray
2 in myArray
# Out:
# Any["Me", 1, 2.3, "another Test"]
# false

# %%
for item ∈ myArray
    println(item)
end
# Out:
# Me
# 1
# 2.3
# another Test

# %% [markdown]
# ### Slice Array

# %%
myArray[1:2]
myArray[3:end]
newArray = myArray[:]
newArray[1]=["Nom", "Prenom"]
print(newArray)
# Out:
# Any[["Nom", "Prenom"], 1, 2.3, "another Test"]

# %%
push!(newArray, 900)
# Out:
# 5-element Vector{Any}:
#     ["Nom", "Prenom"]
#    1
#    2.3
#     "another Test"
#  900

# %% [markdown]
# * append! add the elements of the second array to the end of the first:
# * sort! arranges the elements of the array from low to high:
#
# * splice! modifies the array and returns the element that was removed.
# * popfirst! deletes and returns the first element:
# * push! insert an element at the beginning of the array
# * deleteat! removes the element at a given index without return his value
# * insert!  inserts an element at a given index:
# * collect function breaks a string or another sequence into individual elements
# * split splits a string into words with delimiter as optional argument
# * join  takes an array of strings and concatenates the elements with delimiter as optional argument

# %%
append!(myArray, newArray)
myArray2 = ["Ake","Momo","Etiam","Lomé"]
print(myArray2)
# tri = sort!(myArray)
MAJ = uppercase.(myArray2)
print(MAJ)
maSuppr = splice!(MAJ,2)
print(maSuppr,MAJ)
# Out:
# ["Ake", "Momo", "Etiam", "Lomé"]["AKE", "MOMO", "ETIAM", "LOMÉ"]MOMO["AKE", "ETIAM", "LOMÉ"]

# %% [markdown]
# * ≡ (\equiv TAB) or === operator
# * make copy of array : t2 = t[:]; # t2 = copy(t)
