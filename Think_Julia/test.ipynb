# %%
√25
# Out:
# 5.0

# %%
10 ÷ 3
# Out:
# 3

# %%
45 // 50
# Out:
# 9//10

# %%
x=4
5x
# Out:
# 20

# %%
#= 
Mon commentaire

=#

# %%
my_name = """Mon nom"""
first(my_name)
# Out:
# 'M': ASCII/Unicode U+004D (category Lu: Letter, uppercase)

# %%
rand(6,3,3)
# Out:
# 6×3×3 Array{Float64, 3}:
# [:, :, 1] =
#  0.647555  0.767863   0.694164
#  0.593515  0.740088   0.712124
#  0.693307  0.682948   0.35452
#  0.971958  0.877411   0.282566
#  0.547729  0.474724   0.247713
#  0.716123  0.0572354  0.829178
#
# [:, :, 2] =
#  0.513224  0.257013   0.223961
#  0.54781   0.0907664  0.13977
#  0.988847  0.490241   0.847488
#  0.462623  0.948597   0.552472
#  0.926707  0.830855   0.613504
#  0.237331  0.0291764  0.745804
#
# [:, :, 3] =
#  0.0631894  0.212286   0.410452
#  0.195542   0.568645   0.729483
#  0.402842   0.344737   0.100827
#  0.90917    0.0477207  0.274515
#  0.743011   0.778031   0.694573
#  0.223721   0.131438   0.348158

# %%
my_array = ["AKE","Moi",7]
# Out:
# 3-element Vector{Any}:
#   "AKE"
#   "Moi"
#  7

# %%
my_fruits = ["Mango","Banana"]
# Out:
# 2-element Vector{String}:
#  "Mango"
#  "Banana"

# %%
my_fruits = [my_fruits;"apple"]
# Out:
# 3-element Vector{String}:
#  "Mango"
#  "Banana"
#  "apple"

# %%
isinteger()

# %%
🤠 = 18
0

# %%
while 🤠 
    
end

# %%
function printlyrics()
    println("I'm a lumberjack, and I'm okay.")
    println("I sleep all night and I work all day.")
end
repeatlyrics()

function repeatlyrics()
    printlyrics()
    printlyrics()
end
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# repeatlyrics (generic function with 1 method)

# %%
42 =n
print(n)
# Out:
# syntax: invalid assignment location "42" around /home/mikollect/Téléchargements/MWB/Mentors_Without_Borders/Think_Julia/test.ipynb:1
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Téléchargements/MWB/Mentors_Without_Borders/Think_Julia/test.ipynb:1

# %%
x=y=1
println(x,y)
# Out:
# 11
